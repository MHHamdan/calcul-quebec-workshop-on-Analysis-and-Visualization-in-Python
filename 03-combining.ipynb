# %% [markdown]
# # Data Analysis and Visualization in Python
# ## Combining DataFrames with pandas
# Questions
# * Can I work with data from multiple sources?
# * How can I combine data from different data sets?
#
# Objectives
# * Combine data from multiple files into a single DataFrame using `concat` and `merge`.
# * Combine two DataFrames using a unique ID found in both DataFrames.

# %% [markdown]
# ## Loading our data

# %%
# First make sure pandas is loaded
import pandas as pd

# Read in the survey csv
surveys_df = pd.read_csv("data/surveys.csv")

# %% [markdown]
# ## Concatenating DataFrames

# %%
# Read in first 10 lines of surveys table
surveys_head10 = surveys_df.head(10)
surveys_head10
# Out:
#    record_id  month  day  year  plot_id species_id sex  hindfoot_length  \
# 0          1      7   16  1977        2         NL   M             32.0
# 1          2      7   16  1977        3         NL   M             33.0
# 2          3      7   16  1977        2         DM   F             37.0
# 3          4      7   16  1977        7         DM   M             36.0
# 4          5      7   16  1977        3         DM   M             35.0
# 5          6      7   16  1977        1         PF   M             14.0
# 6          7      7   16  1977        2         PE   F              NaN
# 7          8      7   16  1977        1         DM   M             37.0
# 8          9      7   16  1977        1         DM   F             34.0
# 9         10      7   16  1977        6         PF   F             20.0
#
#    weight
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN
# 5     NaN
# 6     NaN
# 7     NaN
# 8     NaN
# 9     NaN

# %%
# Grab the last 10 rows
surveys_tail10 = surveys_df.tail(10)
surveys_tail10
# Out:
#        record_id  month  day  year  plot_id species_id  sex  hindfoot_length  \
# 35539      35540     12   31  2002       15         PB    F             26.0
# 35540      35541     12   31  2002       15         PB    F             24.0
# 35541      35542     12   31  2002       15         PB    F             26.0
# 35542      35543     12   31  2002       15         PB    F             27.0
# 35543      35544     12   31  2002       15         US  NaN              NaN
# 35544      35545     12   31  2002       15         AH  NaN              NaN
# 35545      35546     12   31  2002       15         AH  NaN              NaN
# 35546      35547     12   31  2002       10         RM    F             15.0
# 35547      35548     12   31  2002        7         DO    M             36.0
# 35548      35549     12   31  2002        5        NaN  NaN              NaN
#
#        weight
# 35539    23.0
# 35540    31.0
# 35541    29.0
# 35542    34.0
# 35543     NaN
# 35544     NaN
# 35545     NaN
# 35546    14.0
# 35547    51.0
# 35548     NaN

# %%
# Stack the DataFrames on top of each other
vertical_stack = pd.concat([surveys_head10, surveys_tail10], axis=1)
vertical_stack
# Out:
#        record_id  month   day    year  plot_id species_id  sex  \
# 0            1.0    7.0  16.0  1977.0      2.0         NL    M
# 1            2.0    7.0  16.0  1977.0      3.0         NL    M
# 2            3.0    7.0  16.0  1977.0      2.0         DM    F
# 3            4.0    7.0  16.0  1977.0      7.0         DM    M
# 4            5.0    7.0  16.0  1977.0      3.0         DM    M
# 5            6.0    7.0  16.0  1977.0      1.0         PF    M
# 6            7.0    7.0  16.0  1977.0      2.0         PE    F
# 7            8.0    7.0  16.0  1977.0      1.0         DM    M
# 8            9.0    7.0  16.0  1977.0      1.0         DM    F
# 9           10.0    7.0  16.0  1977.0      6.0         PF    F
# 35539        NaN    NaN   NaN     NaN      NaN        NaN  NaN
# 35540        NaN    NaN   NaN     NaN      NaN        NaN  NaN
# 35541        NaN    NaN   NaN     NaN      NaN        NaN  NaN
# 35542        NaN    NaN   NaN     NaN      NaN        NaN  NaN
# 35543        NaN    NaN   NaN     NaN      NaN        NaN  NaN
# 35544        NaN    NaN   NaN     NaN      NaN        NaN  NaN
# 35545        NaN    NaN   NaN     NaN      NaN        NaN  NaN
# 35546        NaN    NaN   NaN     NaN      NaN        NaN  NaN
# 35547        NaN    NaN   NaN     NaN      NaN        NaN  NaN
# 35548        NaN    NaN   NaN     NaN      NaN        NaN  NaN
#
#        hindfoot_length  weight  record_id  month   day    year  plot_id  \
# 0                 32.0     NaN        NaN    NaN   NaN     NaN      NaN
# 1                 33.0     NaN        NaN    NaN   NaN     NaN      NaN
# 2                 37.0     NaN        NaN    NaN   NaN     NaN      NaN
# 3                 36.0     NaN        NaN    NaN   NaN     NaN      NaN
# 4                 35.0     NaN        NaN    NaN   NaN     NaN      NaN
# 5                 14.0     NaN        NaN    NaN   NaN     NaN      NaN
# 6                  NaN     NaN        NaN    NaN   NaN     NaN      NaN
# 7                 37.0     NaN        NaN    NaN   NaN     NaN      NaN
# 8                 34.0     NaN        NaN    NaN   NaN     NaN      NaN
# 9                 20.0     NaN        NaN    NaN   NaN     NaN      NaN
# 35539              NaN     NaN    35540.0   12.0  31.0  2002.0     15.0
# 35540              NaN     NaN    35541.0   12.0  31.0  2002.0     15.0
# 35541              NaN     NaN    35542.0   12.0  31.0  2002.0     15.0
# 35542              NaN     NaN    35543.0   12.0  31.0  2002.0     15.0
# 35543              NaN     NaN    35544.0   12.0  31.0  2002.0     15.0
# 35544              NaN     NaN    35545.0   12.0  31.0  2002.0     15.0
# 35545              NaN     NaN    35546.0   12.0  31.0  2002.0     15.0
# 35546              NaN     NaN    35547.0   12.0  31.0  2002.0     10.0
# 35547              NaN     NaN    35548.0   12.0  31.0  2002.0      7.0
# 35548              NaN     NaN    35549.0   12.0  31.0  2002.0      5.0
#
#       species_id  sex  hindfoot_length  weight
# 0            NaN  NaN              NaN     NaN
# 1            NaN  NaN              NaN     NaN
# 2            NaN  NaN              NaN     NaN
# 3            NaN  NaN              NaN     NaN
# 4            NaN  NaN              NaN     NaN
# 5            NaN  NaN              NaN     NaN
# 6            NaN  NaN              NaN     NaN
# 7            NaN  NaN              NaN     NaN
# 8            NaN  NaN              NaN     NaN
# 9            NaN  NaN              NaN     NaN
# 35539         PB    F             26.0    23.0
# 35540         PB    F             24.0    31.0
# 35541         PB    F             26.0    29.0
# 35542         PB    F             27.0    34.0
# 35543         US  NaN              NaN     NaN
# 35544         AH  NaN              NaN     NaN
# 35545         AH  NaN              NaN     NaN
# 35546         RM    F             15.0    14.0
# 35547         DO    M             36.0    51.0
# 35548        NaN  NaN              NaN     NaN

# %%
horizantal_stack = pd.concat([surveys_head10, surveys_tail10], axis=0)
horizantal_stack
# Out:
#        record_id  month  day  year  plot_id species_id  sex  hindfoot_length  \
# 0              1      7   16  1977        2         NL    M             32.0
# 1              2      7   16  1977        3         NL    M             33.0
# 2              3      7   16  1977        2         DM    F             37.0
# 3              4      7   16  1977        7         DM    M             36.0
# 4              5      7   16  1977        3         DM    M             35.0
# 5              6      7   16  1977        1         PF    M             14.0
# 6              7      7   16  1977        2         PE    F              NaN
# 7              8      7   16  1977        1         DM    M             37.0
# 8              9      7   16  1977        1         DM    F             34.0
# 9             10      7   16  1977        6         PF    F             20.0
# 35539      35540     12   31  2002       15         PB    F             26.0
# 35540      35541     12   31  2002       15         PB    F             24.0
# 35541      35542     12   31  2002       15         PB    F             26.0
# 35542      35543     12   31  2002       15         PB    F             27.0
# 35543      35544     12   31  2002       15         US  NaN              NaN
# 35544      35545     12   31  2002       15         AH  NaN              NaN
# 35545      35546     12   31  2002       15         AH  NaN              NaN
# 35546      35547     12   31  2002       10         RM    F             15.0
# 35547      35548     12   31  2002        7         DO    M             36.0
# 35548      35549     12   31  2002        5        NaN  NaN              NaN
#
#        weight
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
# 5         NaN
# 6         NaN
# 7         NaN
# 8         NaN
# 9         NaN
# 35539    23.0
# 35540    31.0
# 35541    29.0
# 35542    34.0
# 35543     NaN
# 35544     NaN
# 35545     NaN
# 35546    14.0
# 35547    51.0
# 35548     NaN

# %%
# Reset index values of the dataframe
# The drop=True option avoids adding new index column with old index values
vertical_stack = vertical_stack.reset_index(drop=True)
vertical_stack
# Out:
#     record_id  month   day    year  plot_id species_id  sex  hindfoot_length  \
# 0         1.0    7.0  16.0  1977.0      2.0         NL    M             32.0
# 1         2.0    7.0  16.0  1977.0      3.0         NL    M             33.0
# 2         3.0    7.0  16.0  1977.0      2.0         DM    F             37.0
# 3         4.0    7.0  16.0  1977.0      7.0         DM    M             36.0
# 4         5.0    7.0  16.0  1977.0      3.0         DM    M             35.0
# 5         6.0    7.0  16.0  1977.0      1.0         PF    M             14.0
# 6         7.0    7.0  16.0  1977.0      2.0         PE    F              NaN
# 7         8.0    7.0  16.0  1977.0      1.0         DM    M             37.0
# 8         9.0    7.0  16.0  1977.0      1.0         DM    F             34.0
# 9        10.0    7.0  16.0  1977.0      6.0         PF    F             20.0
# 10        NaN    NaN   NaN     NaN      NaN        NaN  NaN              NaN
# 11        NaN    NaN   NaN     NaN      NaN        NaN  NaN              NaN
# 12        NaN    NaN   NaN     NaN      NaN        NaN  NaN              NaN
# 13        NaN    NaN   NaN     NaN      NaN        NaN  NaN              NaN
# 14        NaN    NaN   NaN     NaN      NaN        NaN  NaN              NaN
# 15        NaN    NaN   NaN     NaN      NaN        NaN  NaN              NaN
# 16        NaN    NaN   NaN     NaN      NaN        NaN  NaN              NaN
# 17        NaN    NaN   NaN     NaN      NaN        NaN  NaN              NaN
# 18        NaN    NaN   NaN     NaN      NaN        NaN  NaN              NaN
# 19        NaN    NaN   NaN     NaN      NaN        NaN  NaN              NaN
#
#     weight  record_id  month   day    year  plot_id species_id  sex  \
# 0      NaN        NaN    NaN   NaN     NaN      NaN        NaN  NaN
# 1      NaN        NaN    NaN   NaN     NaN      NaN        NaN  NaN
# 2      NaN        NaN    NaN   NaN     NaN      NaN        NaN  NaN
# 3      NaN        NaN    NaN   NaN     NaN      NaN        NaN  NaN
# 4      NaN        NaN    NaN   NaN     NaN      NaN        NaN  NaN
# 5      NaN        NaN    NaN   NaN     NaN      NaN        NaN  NaN
# 6      NaN        NaN    NaN   NaN     NaN      NaN        NaN  NaN
# 7      NaN        NaN    NaN   NaN     NaN      NaN        NaN  NaN
# 8      NaN        NaN    NaN   NaN     NaN      NaN        NaN  NaN
# 9      NaN        NaN    NaN   NaN     NaN      NaN        NaN  NaN
# 10     NaN    35540.0   12.0  31.0  2002.0     15.0         PB    F
# 11     NaN    35541.0   12.0  31.0  2002.0     15.0         PB    F
# 12     NaN    35542.0   12.0  31.0  2002.0     15.0         PB    F
# 13     NaN    35543.0   12.0  31.0  2002.0     15.0         PB    F
# 14     NaN    35544.0   12.0  31.0  2002.0     15.0         US  NaN
# 15     NaN    35545.0   12.0  31.0  2002.0     15.0         AH  NaN
# 16     NaN    35546.0   12.0  31.0  2002.0     15.0         AH  NaN
# 17     NaN    35547.0   12.0  31.0  2002.0     10.0         RM    F
# 18     NaN    35548.0   12.0  31.0  2002.0      7.0         DO    M
# 19     NaN    35549.0   12.0  31.0  2002.0      5.0        NaN  NaN
#
#     hindfoot_length  weight
# 0               NaN     NaN
# 1               NaN     NaN
# 2               NaN     NaN
# 3               NaN     NaN
# 4               NaN     NaN
# 5               NaN     NaN
# 6               NaN     NaN
# 7               NaN     NaN
# 8               NaN     NaN
# 9               NaN     NaN
# 10             26.0    23.0
# 11             24.0    31.0
# 12             26.0    29.0
# 13             27.0    34.0
# 14              NaN     NaN
# 15              NaN     NaN
# 16              NaN     NaN
# 17             15.0    14.0
# 18             36.0    51.0
# 19              NaN     NaN

# %%
horizantal_stack = horizantal_stack.reset_index(drop=True)
horizantal_stack
# Out:
#     record_id  month  day  year  plot_id species_id  sex  hindfoot_length  \
# 0           1      7   16  1977        2         NL    M             32.0
# 1           2      7   16  1977        3         NL    M             33.0
# 2           3      7   16  1977        2         DM    F             37.0
# 3           4      7   16  1977        7         DM    M             36.0
# 4           5      7   16  1977        3         DM    M             35.0
# 5           6      7   16  1977        1         PF    M             14.0
# 6           7      7   16  1977        2         PE    F              NaN
# 7           8      7   16  1977        1         DM    M             37.0
# 8           9      7   16  1977        1         DM    F             34.0
# 9          10      7   16  1977        6         PF    F             20.0
# 10      35540     12   31  2002       15         PB    F             26.0
# 11      35541     12   31  2002       15         PB    F             24.0
# 12      35542     12   31  2002       15         PB    F             26.0
# 13      35543     12   31  2002       15         PB    F             27.0
# 14      35544     12   31  2002       15         US  NaN              NaN
# 15      35545     12   31  2002       15         AH  NaN              NaN
# 16      35546     12   31  2002       15         AH  NaN              NaN
# 17      35547     12   31  2002       10         RM    F             15.0
# 18      35548     12   31  2002        7         DO    M             36.0
# 19      35549     12   31  2002        5        NaN  NaN              NaN
#
#     weight
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
# 5      NaN
# 6      NaN
# 7      NaN
# 8      NaN
# 9      NaN
# 10    23.0
# 11    31.0
# 12    29.0
# 13    34.0
# 14     NaN
# 15     NaN
# 16     NaN
# 17    14.0
# 18    51.0
# 19     NaN

# %% [markdown]
# ### Writing Out Data to CSV

# %%
# Write DataFrame to CSV without the index
vertical_stack.to_csv('surveys_sub.csv', index=False)

# %%
# Read our output back into python and make sure all looks good
new_output = pd.read_csv('surveys_sub.csv')
new_output
# Out:
#     record_id  month   day    year  plot_id species_id  sex  hindfoot_length  \
# 0         1.0    7.0  16.0  1977.0      2.0         NL    M             32.0
# 1         2.0    7.0  16.0  1977.0      3.0         NL    M             33.0
# 2         3.0    7.0  16.0  1977.0      2.0         DM    F             37.0
# 3         4.0    7.0  16.0  1977.0      7.0         DM    M             36.0
# 4         5.0    7.0  16.0  1977.0      3.0         DM    M             35.0
# 5         6.0    7.0  16.0  1977.0      1.0         PF    M             14.0
# 6         7.0    7.0  16.0  1977.0      2.0         PE    F              NaN
# 7         8.0    7.0  16.0  1977.0      1.0         DM    M             37.0
# 8         9.0    7.0  16.0  1977.0      1.0         DM    F             34.0
# 9        10.0    7.0  16.0  1977.0      6.0         PF    F             20.0
# 10        NaN    NaN   NaN     NaN      NaN        NaN  NaN              NaN
# 11        NaN    NaN   NaN     NaN      NaN        NaN  NaN              NaN
# 12        NaN    NaN   NaN     NaN      NaN        NaN  NaN              NaN
# 13        NaN    NaN   NaN     NaN      NaN        NaN  NaN              NaN
# 14        NaN    NaN   NaN     NaN      NaN        NaN  NaN              NaN
# 15        NaN    NaN   NaN     NaN      NaN        NaN  NaN              NaN
# 16        NaN    NaN   NaN     NaN      NaN        NaN  NaN              NaN
# 17        NaN    NaN   NaN     NaN      NaN        NaN  NaN              NaN
# 18        NaN    NaN   NaN     NaN      NaN        NaN  NaN              NaN
# 19        NaN    NaN   NaN     NaN      NaN        NaN  NaN              NaN
#
#     weight  record_id.1  month.1  day.1  year.1  plot_id.1 species_id.1 sex.1  \
# 0      NaN          NaN      NaN    NaN     NaN        NaN          NaN   NaN
# 1      NaN          NaN      NaN    NaN     NaN        NaN          NaN   NaN
# 2      NaN          NaN      NaN    NaN     NaN        NaN          NaN   NaN
# 3      NaN          NaN      NaN    NaN     NaN        NaN          NaN   NaN
# 4      NaN          NaN      NaN    NaN     NaN        NaN          NaN   NaN
# 5      NaN          NaN      NaN    NaN     NaN        NaN          NaN   NaN
# 6      NaN          NaN      NaN    NaN     NaN        NaN          NaN   NaN
# 7      NaN          NaN      NaN    NaN     NaN        NaN          NaN   NaN
# 8      NaN          NaN      NaN    NaN     NaN        NaN          NaN   NaN
# 9      NaN          NaN      NaN    NaN     NaN        NaN          NaN   NaN
# 10     NaN      35540.0     12.0   31.0  2002.0       15.0           PB     F
# 11     NaN      35541.0     12.0   31.0  2002.0       15.0           PB     F
# 12     NaN      35542.0     12.0   31.0  2002.0       15.0           PB     F
# 13     NaN      35543.0     12.0   31.0  2002.0       15.0           PB     F
# 14     NaN      35544.0     12.0   31.0  2002.0       15.0           US   NaN
# 15     NaN      35545.0     12.0   31.0  2002.0       15.0           AH   NaN
# 16     NaN      35546.0     12.0   31.0  2002.0       15.0           AH   NaN
# 17     NaN      35547.0     12.0   31.0  2002.0       10.0           RM     F
# 18     NaN      35548.0     12.0   31.0  2002.0        7.0           DO     M
# 19     NaN      35549.0     12.0   31.0  2002.0        5.0          NaN   NaN
#
#     hindfoot_length.1  weight.1
# 0                 NaN       NaN
# 1                 NaN       NaN
# 2                 NaN       NaN
# 3                 NaN       NaN
# 4                 NaN       NaN
# 5                 NaN       NaN
# 6                 NaN       NaN
# 7                 NaN       NaN
# 8                 NaN       NaN
# 9                 NaN       NaN
# 10               26.0      23.0
# 11               24.0      31.0
# 12               26.0      29.0
# 13               27.0      34.0
# 14                NaN       NaN
# 15                NaN       NaN
# 16                NaN       NaN
# 17               15.0      14.0
# 18               36.0      51.0
# 19                NaN       NaN

# %% [markdown]
# ## Exercise - Concatenating DataFrames
# In `surveys_df`, select rows where the year is 2001. Do the same for year 2002. Concatenate both dataframes. Create a single bar-plot that shows the average weight by sex for each year. Export your results as a CSV and make sure it reads back into python properly.

# %%
# Get data for each year
survey2001 = surveys_df[surveys_df['year'] == 2001]
survey2002 = surveys_df[surveys_df['year'] == 2002]

# Concatenate vertically
survey_all = pd.concat([survey2001, survey2002], axis=1)

# %%
survey_all
# Out:
#        record_id  month   day    year  plot_id species_id  sex  \
# 31710    31711.0    1.0  21.0  2001.0      1.0         PB    F
# 31711    31712.0    1.0  21.0  2001.0      1.0         DM    M
# 31712    31713.0    1.0  21.0  2001.0      1.0         PB    M
# 31713    31714.0    1.0  21.0  2001.0      1.0         DO    M
# 31714    31715.0    1.0  21.0  2001.0      2.0         OT    M
# ...          ...    ...   ...     ...      ...        ...  ...
# 35544        NaN    NaN   NaN     NaN      NaN        NaN  NaN
# 35545        NaN    NaN   NaN     NaN      NaN        NaN  NaN
# 35546        NaN    NaN   NaN     NaN      NaN        NaN  NaN
# 35547        NaN    NaN   NaN     NaN      NaN        NaN  NaN
# 35548        NaN    NaN   NaN     NaN      NaN        NaN  NaN
#
#        hindfoot_length  weight  record_id  month   day    year  plot_id  \
# 31710             26.0    25.0        NaN    NaN   NaN     NaN      NaN
# 31711             37.0    43.0        NaN    NaN   NaN     NaN      NaN
# 31712             29.0    44.0        NaN    NaN   NaN     NaN      NaN
# 31713             34.0    53.0        NaN    NaN   NaN     NaN      NaN
# 31714             20.0    27.0        NaN    NaN   NaN     NaN      NaN
# ...                ...     ...        ...    ...   ...     ...      ...
# 35544              NaN     NaN    35545.0   12.0  31.0  2002.0     15.0
# 35545              NaN     NaN    35546.0   12.0  31.0  2002.0     15.0
# 35546              NaN     NaN    35547.0   12.0  31.0  2002.0     10.0
# 35547              NaN     NaN    35548.0   12.0  31.0  2002.0      7.0
# 35548              NaN     NaN    35549.0   12.0  31.0  2002.0      5.0
#
#       species_id  sex  hindfoot_length  weight
# 31710        NaN  NaN              NaN     NaN
# 31711        NaN  NaN              NaN     NaN
# 31712        NaN  NaN              NaN     NaN
# 31713        NaN  NaN              NaN     NaN
# 31714        NaN  NaN              NaN     NaN
# ...          ...  ...              ...     ...
# 35544         AH  NaN              NaN     NaN
# 35545         AH  NaN              NaN     NaN
# 35546         RM    F             15.0    14.0
# 35547         DO    M             36.0    51.0
# 35548        NaN  NaN              NaN     NaN
#
# [3839 rows x 18 columns]

# %%
# Get the average weight by sex for each year
weight_year = survey_all.groupby(['year', 'sex'])['weight'].mean().unstack()
weight_year
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_30756/3313509327.py in <module>
#       1 # Get the average weight by sex for each year
# ----> 2 weight_year = survey_all.groupby(['year', 'sex'])['weight'].mean().unstack()
#       3 weight_year
#
# /opt/ipython-kernel/lib/python3.7/site-packages/pandas/core/frame.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, dropna)
#    6519             squeeze=squeeze,
#    6520             observed=observed,
# -> 6521             dropna=dropna,
#    6522         )
#    6523
#
# /opt/ipython-kernel/lib/python3.7/site-packages/pandas/core/groupby/groupby.py in __init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, squeeze, observed, mutated, dropna)
#     531                 observed=observed,
#     532                 mutated=self.mutated,
# --> 533                 dropna=self.dropna,
#     534             )
#     535
#
# /opt/ipython-kernel/lib/python3.7/site-packages/pandas/core/groupby/grouper.py in get_grouper(obj, key, axis, level, sort, observed, mutated, validate, dropna)
#     807                 dropna=dropna,
#     808             )
# --> 809             if not isinstance(gpr, Grouping)
#     810             else gpr
#     811         )
#
# /opt/ipython-kernel/lib/python3.7/site-packages/pandas/core/groupby/grouper.py in __init__(self, index, grouper, obj, name, level, sort, observed, in_axis, dropna)
#     515                 if getattr(self.grouper, "ndim", 1) != 1:
#     516                     t = self.name or str(type(self.grouper))
# --> 517                     raise ValueError(f"Grouper for '{t}' not 1-dimensional")
#     518                 self.grouper = self.index.map(self.grouper)
#     519                 if not (
#
# ValueError: Grouper for 'year' not 1-dimensional

# %%
# Writing to file while keeping the index
weight_year.to_csv("weight_for_year.csv", index=True)

# Reading it back in with a specified index column
pd.read_csv("weight_for_year.csv", index_col='year')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_30756/3118807343.py in <module>
#       1 # Writing to file while keeping the index
# ----> 2 weight_year.to_csv("weight_for_year.csv", index=True)
#       3
#       4 # Reading it back in with a specified index column
#       5 pd.read_csv("weight_for_year.csv", index_col='year')
#
# NameError: name 'weight_year' is not defined

# %% [markdown]
# ## Joining Two DataFrames

# %%
# Import a small subset of the species data designed for this part of the lesson
species_sub = pd.read_csv('data/speciesSubset.csv')
species_sub
# Out:
#   species_id       genus   species    taxa
# 0         DM   Dipodomys  merriami  Rodent
# 1         NL     Neotoma  albigula  Rodent
# 2         PE  Peromyscus  eremicus  Rodent

# %% [markdown]
# ### Identifying join keys

# %%
surveys_head10.columns
# Out:
# Index(['record_id', 'month', 'day', 'year', 'plot_id', 'species_id', 'sex',
#        'hindfoot_length', 'weight'],
#       dtype='object')

# %%
species_sub.columns
# Out:
# Index(['species_id', 'genus', 'species', 'taxa'], dtype='object')

# %% [markdown]
# ### Inner joins

# %% [markdown]
# ![Inner join of tables A and B](https://datacarpentry.org/python-ecology-lesson/fig/inner-join.png)

# %%
merged_inner = pd.merge(left=surveys_head10, right=species_sub,
                        left_on='species_id', right_on='species_id')
# What's the size of the output data?
merged_inner.shape
# Out:
# (8, 12)

# %%
merged_inner
# Out:
#    record_id  month  day  year  plot_id species_id sex  hindfoot_length  \
# 0          1      7   16  1977        2         NL   M             32.0
# 1          2      7   16  1977        3         NL   M             33.0
# 2          3      7   16  1977        2         DM   F             37.0
# 3          4      7   16  1977        7         DM   M             36.0
# 4          5      7   16  1977        3         DM   M             35.0
# 5          8      7   16  1977        1         DM   M             37.0
# 6          9      7   16  1977        1         DM   F             34.0
# 7          7      7   16  1977        2         PE   F              NaN
#
#    weight       genus   species    taxa
# 0     NaN     Neotoma  albigula  Rodent
# 1     NaN     Neotoma  albigula  Rodent
# 2     NaN   Dipodomys  merriami  Rodent
# 3     NaN   Dipodomys  merriami  Rodent
# 4     NaN   Dipodomys  merriami  Rodent
# 5     NaN   Dipodomys  merriami  Rodent
# 6     NaN   Dipodomys  merriami  Rodent
# 7     NaN  Peromyscus  eremicus  Rodent

# %% [markdown]
# ### Left joins

# %% [markdown]
# ![Left join of tables A and B](https://datacarpentry.org/python-ecology-lesson/fig/left-join.png)

# %%
merged_left = pd.merge(left=surveys_head10, right=species_sub,
                       how='left', on='species_id')
# What's the size of the output data?
merged_left.shape
# Out:
# (10, 12)

# %%
merged_left
# Out:
#    record_id  month  day  year  plot_id species_id sex  hindfoot_length  \
# 0          1      7   16  1977        2         NL   M             32.0
# 1          2      7   16  1977        3         NL   M             33.0
# 2          3      7   16  1977        2         DM   F             37.0
# 3          4      7   16  1977        7         DM   M             36.0
# 4          5      7   16  1977        3         DM   M             35.0
# 5          6      7   16  1977        1         PF   M             14.0
# 6          7      7   16  1977        2         PE   F              NaN
# 7          8      7   16  1977        1         DM   M             37.0
# 8          9      7   16  1977        1         DM   F             34.0
# 9         10      7   16  1977        6         PF   F             20.0
#
#    weight       genus   species    taxa
# 0     NaN     Neotoma  albigula  Rodent
# 1     NaN     Neotoma  albigula  Rodent
# 2     NaN   Dipodomys  merriami  Rodent
# 3     NaN   Dipodomys  merriami  Rodent
# 4     NaN   Dipodomys  merriami  Rodent
# 5     NaN         NaN       NaN     NaN
# 6     NaN  Peromyscus  eremicus  Rodent
# 7     NaN   Dipodomys  merriami  Rodent
# 8     NaN   Dipodomys  merriami  Rodent
# 9     NaN         NaN       NaN     NaN

# %% [markdown]
# ### Other join types
# * `how='right'` : all rows from the right DataFrame are kept
# * `how='outer'` : all pairwise combinations of rows from both DataFrames

# %% [markdown]
# ## Exercise - Joining all data
# `1`. Create a new DataFrame by joining the contents of the `surveys.csv` and `species.csv` tables.

# %%
species_df = pd.read_csv("data/species.csv")
merged_left = pd.merge(left=surveys_df, right=species_df, how='left', on='species_id')
merged_left.shape
# Out:
# (35549, 12)

# %% [markdown]
# `2`. Calculate and plot the distribution of surveys (i.e. the number of `record_id`) by `taxa` for each `plot_id`.

# %%
taxa_site = merged_left.groupby(['plot_id', 'taxa'])['record_id'].count().unstack()
taxa_site.head()
# Out:
# taxa     Bird  Rabbit  Reptile  Rodent  Rodent-not censused
# plot_id
# 1        11.0     2.0      NaN  1909.0                 19.0
# 2        17.0     3.0      1.0  1958.0                 14.0
# 3        17.0     5.0      NaN  1690.0                 19.0
# 4         5.0     NaN      NaN  1934.0                 24.0
# 5         5.0     1.0      NaN  1145.0                 15.0

# %%
taxa_site.plot(kind='line', stacked=True)
# Out:
# <AxesSubplot:xlabel='plot_id'>

# %% [markdown]
# `3`. Calculate and plot the distribution of `taxa` by `sex` for each `plot_id`.

# %%
# Data cleanup
merged_left.loc[merged_left['sex'].isnull(), 'sex'] = "F|M"
merged_left.loc[~merged_left['sex'].isin(["F", "F|M", "M"]), 'sex'] = "F|M"

# %%
ntaxa_sex_site = merged_left.groupby(['plot_id',
                                      'sex'])['taxa'].nunique().reset_index(level=1)
ntaxa_sex_site.head()
# Out:
#          sex  taxa
# plot_id
# 1          F     1
# 1        F|M     4
# 1          M     1
# 2          F     1
# 2        F|M     5

# %%
# Use pivot_table() instead of unstack()
ntaxa_sex_site = ntaxa_sex_site.pivot_table(values='taxa', columns='sex',
                                            index=ntaxa_sex_site.index)
ntaxa_sex_site.head()
# Out:
# sex      F  F|M  M
# plot_id
# 1        1    4  1
# 2        1    5  1
# 3        1    4  1
# 4        1    3  1
# 5        1    4  1

# %%
ntaxa_sex_site.plot(kind="bar", stacked=True, legend=False)
# Out:
# <AxesSubplot:xlabel='plot_id'>
